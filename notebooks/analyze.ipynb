# %% [markdown]
# # Проанализируем данные

# %%
import pandas as pd
import polars as pl


def read(n: str, **kwargs):
    return pl.read_csv(f"../data/{n}", **kwargs).to_pandas()


public = read("public/data.csv")
private = read("private/data.csv")

# %%
def analayze(data: pd.DataFrame):
    missing_values_count = data.isnull().sum()
    missing_values_percent = round(
        (data.isnull().sum() / len(data)) * 100
    ).astype(int)
    unique_values_count = data.nunique()
    unique_values_percent = round((data.nunique() / len(data)) * 100).astype(
        int
    )

    return pd.DataFrame(
        {
            "Missing Values Count": missing_values_count,
            "Missing Values Percent (%)": missing_values_percent,
            "Unique Values Count": unique_values_count,
            "Unique Values Percent (%)": unique_values_percent,
        }
    )

# %%
analayze(public)
# Out:
#                           Missing Values Count  Missing Values Percent (%)  \
# blend_id                                     0                           0
# smiles                                       0                           0
# oil_property_param_value                    12                           1
#
#                           Unique Values Count  Unique Values Percent (%)
# blend_id                                  341                         25
# smiles                                     53                          4
# oil_property_param_value                  322                         23

# %%
analayze(private.loc[private["oil_property_param_title"] == "ad7e6027-00b8-4c27-918c-d1561f949ad8"])
# Out:
#                                 Missing Values Count  \
# oil_type                                         588
# blend_id                                           0
# oil_property_param_title                           0
# oil_property_param_value                         411
# component_name                                     0
# component_class                                16775
# polymer                                        16775
# component_property_param_title                     0
# component_property_param_value                 28402
# smiles                                         16775
#
#                                 Missing Values Percent (%)  \
# oil_type                                                 1
# blend_id                                                 0
# oil_property_param_title                                 0
# oil_property_param_value                                 1
# component_name                                           0
# component_class                                         38
# polymer                                                 38
# component_property_param_title                           0
# component_property_param_value                          64
# smiles                                                  38
#
#                                 Unique Values Count  Unique Values Percent (%)
# oil_type                                          4                          0
# blend_id                                        343                          1
# oil_property_param_title                          1                          0
# oil_property_param_value                        324                          1
# component_name                                  109                          0
# component_class                                  13                          0
# polymer                                           2                          0
# component_property_param_title                   43                          0
# component_property_param_value                 1015                          2
# smiles                                           51                          0

# %%
private.loc[private["oil_property_param_title"] == "ad7e6027-00b8-4c27-918c-d1561f949ad8"]
# Out:
#                                     oil_type  \
# 358     3fa07e0a-415c-496d-b88b-557855cb3e77
# 359     3fa07e0a-415c-496d-b88b-557855cb3e77
# 360     3fa07e0a-415c-496d-b88b-557855cb3e77
# 361     3fa07e0a-415c-496d-b88b-557855cb3e77
# 362     3fa07e0a-415c-496d-b88b-557855cb3e77
# ...                                      ...
# 359362  60c1209c-8e77-467e-a01f-b6321801a260
# 359363  60c1209c-8e77-467e-a01f-b6321801a260
# 359364  60c1209c-8e77-467e-a01f-b6321801a260
# 359365  60c1209c-8e77-467e-a01f-b6321801a260
# 359366  60c1209c-8e77-467e-a01f-b6321801a260
#
#                                     blend_id  \
# 358     49743a76-a614-11ee-9529-005056921581
# 359     49743a76-a614-11ee-9529-005056921581
# 360     49743a76-a614-11ee-9529-005056921581
# 361     49743a76-a614-11ee-9529-005056921581
# 362     49743a76-a614-11ee-9529-005056921581
# ...                                      ...
# 359362  45f1e44a-9410-11ee-8abf-005056921581
# 359363  45f1e44a-9410-11ee-8abf-005056921581
# 359364  45f1e44a-9410-11ee-8abf-005056921581
# 359365  45f1e44a-9410-11ee-8abf-005056921581
# 359366  45f1e44a-9410-11ee-8abf-005056921581
#
#                     oil_property_param_title  oil_property_param_value  \
# 358     ad7e6027-00b8-4c27-918c-d1561f949ad8                  103300.0
# 359     ad7e6027-00b8-4c27-918c-d1561f949ad8                  103300.0
# 360     ad7e6027-00b8-4c27-918c-d1561f949ad8                  103300.0
# 361     ad7e6027-00b8-4c27-918c-d1561f949ad8                  103300.0
# 362     ad7e6027-00b8-4c27-918c-d1561f949ad8                  103300.0
# ...                                      ...                       ...
# 359362  ad7e6027-00b8-4c27-918c-d1561f949ad8                   12510.0
# 359363  ad7e6027-00b8-4c27-918c-d1561f949ad8                   12510.0
# 359364  ad7e6027-00b8-4c27-918c-d1561f949ad8                   12510.0
# 359365  ad7e6027-00b8-4c27-918c-d1561f949ad8                   12510.0
# 359366  ad7e6027-00b8-4c27-918c-d1561f949ad8                   12510.0
#
#                               component_name     component_class polymer  \
# 358     615537f6-1f8f-4240-a5e9-8f7be344ecd3  базовое масло 1 гр      no
# 359     615537f6-1f8f-4240-a5e9-8f7be344ecd3  базовое масло 1 гр      no
# 360     615537f6-1f8f-4240-a5e9-8f7be344ecd3  базовое масло 1 гр      no
# 361     615537f6-1f8f-4240-a5e9-8f7be344ecd3  базовое масло 1 гр      no
# 362     615537f6-1f8f-4240-a5e9-8f7be344ecd3  базовое масло 1 гр      no
# ...                                      ...                 ...     ...
# 359362  1433126f-b36a-4e69-ad2f-ee12d8b46275                None    None
# 359363  1433126f-b36a-4e69-ad2f-ee12d8b46275                None    None
# 359364  1433126f-b36a-4e69-ad2f-ee12d8b46275                None    None
# 359365  1433126f-b36a-4e69-ad2f-ee12d8b46275                None    None
# 359366  1433126f-b36a-4e69-ad2f-ee12d8b46275                None    None
#
#               component_property_param_title  component_property_param_value  \
# 358     02236ee6-5eec-4368-a2e4-6f2e73fb0f96                          0.0000
# 359     2511714c-ab50-4566-bc92-8e4095d87d01                          0.0000
# 360     38b06d9a-bcf2-40de-8e1b-9c3988c42406                          0.0001
# 361     f216a0c7-d453-4b15-9b4a-7647cbe2d874                          0.0990
# 362     9703e283-f529-4fdb-8d84-24413b2b4338                          0.0001
# ...                                      ...                             ...
# 359362  a59e9688-c5e5-4488-a911-2fc21e0355be                             NaN
# 359363  f400be8b-3bed-4f17-8a12-9fabd9b73586                             NaN
# 359364  1931ea10-9783-4065-a77c-04532d7d0559                             NaN
# 359365  c11112c4-487f-4e2c-812d-84a29b240b69                             NaN
# 359366  c11112c4-487f-4e2c-812d-84a29b240b69                             NaN
#
#        smiles
# 358     CCCCC
# 359     CCCCC
# 360     CCCCC
# 361     CCCCC
# 362     CCCCC
# ...       ...
# 359362   None
# 359363   None
# 359364   None
# 359365   None
# 359366   None
#
# [44257 rows x 10 columns]
